# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn import tree
from collections import Counter

# %%
titanic_data = pd.read_csv("/Users/cram/Downloads/train.csv")
x = titanic_data.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis = 1)
y = titanic_data.Survived

# %%
rf_clf = RandomForestClassifier()

# %%
param = {'n_estimators':[10,20,30], 'max_depth':[2,5,7,10]}

# %%
grid_clf = GridSearchCV(rf_clf,param,cv=5)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y)

# %%
grid_clf.fit(X_train, y_train)
# Out:
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 616, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py", line 1898, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/cram/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'female'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/cram/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-3897456e83bd> in <module>
# ----> 1 grid_clf.fit(X_train, y_train)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1896
#    1897     def __array__(self, dtype=None) -> np.ndarray:
# -> 1898         return np.asarray(self._values, dtype=dtype)
#    1899
#    1900     def __array_wrap__(
#
# ~/opt/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'female'

# %%
grid_clf.best_params_
# Out:
# {'max_depth': 2, 'n_estimators': 10}

# %%
#best_clf = grid_clf.best_estimator_
#feature_importance = best_clf.feature_importances_
#feature_importance_DF = pd.DataFrame('feature':list(X_train),'feature_importance':feature_importance)
#feature_importance_DF.sort_values('feature_importance', ascending = False)

# %%
df1 = pd.read_csv("/Users/cram/Downloads/heart.csv")

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
x = df1[['age', 'sex', 'cp','trestbps','chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df1.target

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y)

# %%
#np.random.seed(0)

#rf = RandomForestClassifier(10, max_depth=5)

#sns.set_color_codes("muted")
#sns.barplot(x="feature_importances", y="feature", data=fi_sored,
            #label="importance", color="b")

# %%
df = pd.read_csv("/Users/cram/Downloads/training_mush.csv")

# %%
df
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            0          3        1     5                1
# 1             2            0          4        0     5                1
# 2             2            0          3        0     2                1
# 3             0            0          3        0     5                1
# 4             2            3          3        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 6088          2            0          3        0     5                1
# 6089          3            2          2        0     2                1
# 6090          5            2          3        0     1                1
# 6091          3            2          3        0     5                1
# 6092          2            0          9        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0                0          0           9            1  ...
# 1                0          1          10            0  ...
# 2                0          0           7            0  ...
# 3                1          0           2            0  ...
# 4                0          0          10            1  ...
# ...            ...        ...         ...          ...  ...
# 6088             1          0           4            1  ...
# 6089             0          1           0            1  ...
# 6090             0          1           9            0  ...
# 6091             1          0           2            0  ...
# 6092             0          0           3            0  ...
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          3                       7          0           2
# 1                          7                       4          0           2
# 2                          0                       4          0           2
# 3                          7                       7          0           2
# 4                          3                       6          0           2
# ...                      ...                     ...        ...         ...
# 6088                       7                       7          0           2
# 6089                       6                       7          0           2
# 6090                       7                       7          0           2
# 6091                       7                       7          0           2
# 6092                       4                       4          0           2
#
#       ring-number  ring-type  spore-print-color  population  habitat  class
# 0               1          4                  3           5        0      0
# 1               1          0                  7           4        0      1
# 2               1          2                  1           5        1      1
# 3               2          4                  7           3        1      0
# 4               1          4                  2           5        0      0
# ...           ...        ...                ...         ...      ...    ...
# 6088            1          0                  3           3        1      0
# 6089            1          0                  7           4        0      1
# 6090            1          4                  3           4        0      1
# 6091            2          4                  7           3        1      0
# 6092            1          2                  1           4        0      1
#
# [6093 rows x 23 columns]

# %%
X = df.drop(['class'], axis=1)
Y = df['class']

# %%
rf = RandomForestClassifier(random_state=0, criterion='entropy')

# %%
parametrs = {'n_estimators':[10,20,30,40,50], 'max_depth':[1,3,5,7,9,11], 'min_samples_leaf':[1,2,3,4,5,6,7], 'min_samples_split': [2,4,6,8]}

# %%
grid = GridSearchCV(rf,parametrs,cv=3, n_jobs = -1)

# %%
grid.fit(X, Y)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(criterion='entropy',
#                                               random_state=0),
#              n_jobs=-1,
#              param_grid={'max_depth': [1, 3, 5, 7, 9, 11],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [10, 20, 30, 40, 50]})

# %%
best_clf_es = grid.best_estimator_

# %%
best_clf_es
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=9, n_estimators=10,
#                        random_state=0)

# %%
best_clf = grid.best_params_

# %%
best_clf
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=9, n_estimators=10,
#                        random_state=0)

# %%
df_test = pd.read_csv("/Users/cram/Downloads/testing_mush.csv")

# %%
best_clf_es.predict(df_test).sum()
# Out:
# 976

# %%
invasion = pd.read_csv("/Users/cram/Downloads/invasion.csv")
operative_information = pd.read_csv("/Users/cram/Downloads/operative_information.csv")

# %%
invasion.head()
# Out:
#        class  g_reflection  i_reflection       speed  brightness  \
# 0  transport      2.190672      6.716633   62.168208    0.347465
# 1  transport      3.453276      8.995909   62.994707    0.590094
# 2  transport      2.432994      6.938691   62.245807    0.329288
# 3    fighter      6.083763      3.019459   18.474555    0.174738
# 4    fighter     12.876769      2.452950  195.805771    0.150446
#
#    time_of_observance     volume
# 0              158221  44.932446
# 1              385972  41.568300
# 2              446482  40.123467
# 3              210125  11.384865
# 4               23109  11.328806

# %%
x1 = invasion.drop(['class'], axis=1)
y1 = invasion['class']

# %%
rf_trans = RandomForestClassifier(criterion='entropy')

# %%
par = {'n_estimators':(1,20,1),'max_depth' : (1,13,2),'min_samples_leaf' :(1,8), 'min_samples_split' :(2,10,2)}

# %%
grid1 = GridSearchCV(rf_trans,par,cv=3, n_jobs = -1)

# %%
grid1.fit(x1, y1)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(criterion='entropy'),
#              n_jobs=-1,
#              param_grid={'max_depth': (1, 13, 2), 'min_samples_leaf': (1, 8),
#                          'min_samples_split': (2, 10, 2),
#                          'n_estimators': (1, 20, 1)})

# %%
best_clf_estum = grid1.best_params_

# %%
operative_information=grid1.predict

# %%
operative_information
# Out:
# <function sklearn.model_selection._search.BaseSearchCV.predict(self, X)>

# %%
s = pd.Series(operative_information).value_counts()

# %%
s
# Out:
# <function BaseSearchCV.predict at 0x7fa1088720d0>    1
# dtype: int64
